# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as wb

# %%
import yfinance as yf

# %%
start = "2018-01-01"
end = "2023-01-01"

BAJIO = yf.download("BBAJIOO.MX", start, end)
GFNORTE = yf.download("GFNORTEO.MX", start, end)
GENTERA = yf.download("GENTERA.MX", start, end)
TELEVISA = yf.download("TLEVISACPO.MX", start, end)
MEGA = yf.download("MEGACPO.MX", start, end)
AMX = yf.download("AMXB.MX", start, end)
GCC = yf.download("GCC.MX", start, end)
CEMEX = yf.download("CEMEXCPO.MX", start, end)
ASUR = yf.download("ASURB.MX", start, end)
GAP = yf.download("GAPB.MX", start, end)
GMXT = yf.download("GMXT.MX", start, end)
TRAXION = yf.download("TRAXIONA.MX", start, end)
VOLARIS = yf.download("VOLARA.MX", start, end)
KIMBER = yf.download("KIMBERA.MX", start, end)
ARCA = yf.download("AC.MX", start, end)
CUERVO = yf.download("CUERVO.MX", start, end)
HERDEZ = yf.download("HERDEZ.MX", start, end)
GRUMA = yf.download("GRUMAB.MX", start, end)
BIMBO = yf.download("BIMBOA.MX", start, end)
LABB = yf.download("LABB.MX", start, end)
LACOMER = yf.download("LACOMERUBC.MX", start, end)
CHEDRAUI = yf.download("CHDRAUIB.MX", start, end)
FEMSA = yf.download("FEMSAUBD.MX", start, end)
LIVERPOOL = yf.download("LIVEPOLC-1.MX", start, end)
ALPEK = yf.download("ALPEKA.MX", start, end)
NEMAK = yf.download("NEMAKA.MX", start, end)
FUNO = yf.download("FUNO11.MX", start, end)
DANHOS = yf.download("DANHOS13.MX", start, end)
TERRA = yf.download("TERRA13.MX", start, end)
PROLOGIS = yf.download("FIBRAPL14.MX", start, end)
MACQUARIE = yf.download("FIBRAMQ12.MX", start, end)
VESTA = yf.download("VESTA.MX", start, end)
OPSIMEX = yf.download("SITES1A-1.MX", start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
tickers= [BAJIO, GFNORTE, GENTERA, TELEVISA, MEGA, AMX, GCC, CEMEX, ASUR, GAP, GMXT, TRAXION, VOLARIS, KIMBER, ARCA, CUERVO, HERDEZ, GRUMA, BIMBO, LABB, LACOMER, CHEDRAUI, FEMSA, LIVERPOOL, ALPEK, NEMAK, FUNO, DANHOS, TERRA, PROLOGIS, MACQUARIE, VESTA, OPSIMEX]

# %%
import matplotlib.pyplot as plt
from pylab import plot

import seaborn as sns

# %%
type(tickers)
# Out:
# list

# %%
serie = pd.Series(tickers)

# %%
type(serie)
# Out:
# pandas.core.series.Series

# %%
lista = serie.tolist()

# %%
type(lista)
# Out:
# list

# %%
lista
# Out:
# [                 Open       High        Low      Close  Adj Close   Volume
#  Date
#  2018-01-02  35.930000  37.000000  35.500000  36.919998  26.368223   969250
#  2018-01-03  37.000000  37.000000  36.200001  36.439999  26.025406   760640
#  2018-01-04  37.000000  37.000000  35.500000  36.330002  25.946848   494018
#  2018-01-05  36.330002  37.000000  36.330002  36.880001  26.339659   687554
#  2018-01-08  36.889999  36.980000  35.820000  36.529999  26.089684   435880
#  ...               ...        ...        ...        ...        ...      ...
#  2022-12-26  63.990002  63.990002  63.000000  63.599998  59.393234    80934
#  2022-12-27  63.500000  63.990002  62.669998  63.490002  59.290512   526572
#  2022-12-28  63.910000  63.910000  61.470001  62.080002  57.973774  1165036
#  2022-12-29  62.310001  62.950001  61.389999  61.630001  57.553539   971887
#  2022-12-30  61.689999  62.389999  61.000000  61.380001  57.320076  1394241
#
#  [1259 rows x 6 columns],
# ...

# %%
data = pd.DataFrame (tickers)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py:568: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
data.to_excel('ALPHA_Returns.xlsx', sheet_name= 'ALPHA', index= False)
